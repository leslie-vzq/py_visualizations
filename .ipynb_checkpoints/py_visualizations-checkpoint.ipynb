# %%
# python_visualizations environment

# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading Datasets

# %% [markdown]
# ## Data 1

# %%
min_wage = pd.read_csv("Minimum Wage Data.csv", encoding='latin1')
# print(min_wage.head())

# %% [markdown]
# ## Data 2

# %%
nba = pd.read_csv("2021-2022 NBA Player Stats.csv")
# print(nba.head())

# %% [markdown]
# ## Data 3

# %%
directory = pd.read_csv("directory.csv")
# print(directory.head())

# %% [markdown]
# ## Data 4

# %%
housing = pd.read_csv("Housing.csv")
# print(housing.head())

# %% [markdown]
# # Visualizations
# ## Data 1

# %%
ca_min_wage = min_wage.loc["California"]
ca_min_wage = ca_min_wage.loc[:,["Year", "State.Minimum.Wage"]]
print(ca_min_wage.head())
# Out:
#             Year  State.Minimum.Wage
# State
# California  1968                1.65
# California  1969                1.65
# California  1970                1.65
# California  1971                1.65
# California  1972                1.65

# %%
plt.plot(ca_min_wage["Year"], ca_min_wage["State.Minimum.Wage"], color = "#4daf4a")
plt.xlabel("Year")
plt.ylabel("CA Minimum Wage (US Dollars)") 
plt.title("CA Minimum Wage 1968-2020")
plt.show()

# colors = {
#    'blue':    '#377eb8', 
#    'orange':  '#ff7f00',
#    'green':   '#4daf4a',
#    'pink':    '#f781bf',
#    'brown':   '#a65628',
#    'purple':  '#984ea3',
#    'gray':    '#999999',
#    'red':     '#e41a1c',
#    'yellow':  '#dede00'
#}

# %% [markdown]
# ## Data 2

# %%
plt.hist(nba["MP"], bins = 20, color = "#377eb8", edgecolor = "black")
plt.xlabel("Minutes Played Per Game")
plt.ylabel("Frequency")
plt.title("NBA Game Time Frequency")
plt.show()
